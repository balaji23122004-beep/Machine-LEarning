# %% [markdown]
# <a href="https://colab.research.google.com/github/balaji23122004-beep/Machine-LEarning/blob/main/Exp%209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

X = np.array([[1],[2],[3],[4],[5]])
y = np.array([1,4,9,16,25])

lin = LinearRegression()
lin.fit(X,y)

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

poly_model = LinearRegression()
poly_model.fit(X_poly,y)

print("Linear:", lin.predict([[6]]))
print("Polynomial:", poly_model.predict(poly.transform([[6]])))
# Out:
# Linear: [29.]
# Polynomial: [36.]
